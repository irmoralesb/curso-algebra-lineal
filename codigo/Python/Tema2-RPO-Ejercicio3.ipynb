# %%
import numpy as np
A = np.array([[1,1],[1,-1],[2,1]])
b = np.array([2,1,3])
AB = np.array([[1,1,2],[1,-1,1],[2,1,3]])
print(np.linalg.matrix_rank(A))
print(np.linalg.matrix_rank(AB))
# Out:
# 2
# 3

# %%
import matplotlib.pyplot as plt
x = np.linspace(-1,2,100)
plt.plot(x,2-x,x,1+x,x,3-2*x)
# Out:
# [<matplotlib.lines.Line2D at 0x7fc3dbade828>,
#  <matplotlib.lines.Line2D at 0x7fc3dbade860>,
#  <matplotlib.lines.Line2D at 0x7fc3dbade908>]
